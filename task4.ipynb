# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv(r"C:\Users\mohan\Downloads\USvideos.csv")

print("First few rows of the dataset:")
print(df.head())

print("\nSummary of the dataset:")
print(df.info())

print("\nDescriptive statistics:")
print(df.describe())

print("\nMissing values in each column:")
print(df.isnull().sum())

df = df.dropna()

print("\nPlotting distributions of numerical variables:")
df.hist(figsize=(10, 10))
plt.show()

for column in df.select_dtypes(include=['float64', 'int64']).columns:
    print(f"\nPlotting distribution for {column}:")
    sns.histplot(df[column], kde=True)
    plt.show()

for column in df.select_dtypes(include=['float64', 'int64']).columns:
    print(f"\nPlotting boxplot for {column}:")
    sns.boxplot(x=df[column])
    plt.show()

print("\nCorrelation matrix:")
numeric_df = df.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_df.corr()
print(correlation_matrix)

print("\nHeatmap of the correlation matrix:")
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

print("\nPair plot to visualize relationships between variables:")
sns.pairplot(numeric_df)
plt.show()
# Out:
# First few rows of the dataset:
#    views  likes  dislikes  comment_count video_id    title channel_title
# 0  15000   1000       100            250       x1  Video A     Channel 1
# 1  25000   1500       150            300       x2  Video B     Channel 2
# 2  35000   2000       120            400       x3  Video C     Channel 3
# 3  12000    800        80            200       x4  Video D     Channel 4
# 4  52000   2500       200            500       x5  Video E     Channel 5
#
# Summary of the dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   views          5 non-null      int64
#  1   likes          5 non-null      int64
#  2   dislikes       5 non-null      int64
#  3   comment_count  5 non-null      int64
#  4   video_id       5 non-null      object
#  5   title          5 non-null      object
#  6   channel_title  5 non-null      object
# dtypes: int64(4), object(3)
# memory usage: 412.0+ bytes
# None
#
# Descriptive statistics:
#              views        likes    dislikes  comment_count
# count      5.00000     5.000000    5.000000       5.000000
# mean   27800.00000  1560.000000  130.000000     330.000000
# std    16269.60356   702.139587   46.904158     120.415946
# min    12000.00000   800.000000   80.000000     200.000000
# 25%    15000.00000  1000.000000  100.000000     250.000000
# 50%    25000.00000  1500.000000  120.000000     300.000000
# 75%    35000.00000  2000.000000  150.000000     400.000000
# max    52000.00000  2500.000000  200.000000     500.000000
#
# Missing values in each column:
# views            0
# likes            0
# dislikes         0
# comment_count    0
# video_id         0
# title            0
# channel_title    0
# dtype: int64
#
# Plotting distributions of numerical variables:
# Plotting distribution for views:
# Plotting distribution for likes:
# Plotting distribution for dislikes:
# Plotting distribution for comment_count:
# Plotting boxplot for views:
# Plotting boxplot for likes:
# Plotting boxplot for dislikes:
# Plotting boxplot for comment_count:
# Correlation matrix:
#                   views     likes  dislikes  comment_count
# views          1.000000  0.990499  0.897640       0.992793
# likes          0.990499  1.000000  0.872977       0.993509
# dislikes       0.897640  0.872977  1.000000       0.863136
# comment_count  0.992793  0.993509  0.863136       1.000000
#
# Heatmap of the correlation matrix:
# Pair plot to visualize relationships between variables:
